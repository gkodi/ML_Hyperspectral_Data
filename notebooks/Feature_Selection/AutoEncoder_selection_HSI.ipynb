# %% [markdown]
# # AutoEncoder Feature Selection
# In this notebook, we will explore a deep learning-based approach for feature selection in hyperspectral data using autoencoders. Specifically, we will use the concrete_autoencoder library to train an autoencoder on our hyperspectral data and select the top K most important features based on the reconstruction error. We will apply this method to a real-world hyperspectral dataset and evaluate the performance of our feature selection approach using a classification task.
#
# **Link to the original code**: [Link](https://github.com/mfbalin/Concrete-Autoencoders)
#
# **Link to the paper**: [Link](https://arxiv.org/abs/1901.09346)
#
# Autoencoders are a type of neural network that learns to reconstruct input data from a compressed representation, also known as the latent space. They consist of two main components: an encoder that maps the input data into the latent space, and a decoder that reconstructs the input data from the latent representation.
#
# Autoencoders have been shown to be effective in feature selection by learning a compressed representation of the input data that retains the most important features. By training the autoencoder on the input data and then examining the importance of the latent features, we can select the top K most important features and discard the rest.
#
# **Important note**🔥🔥! This notebook addresses **regression problems only**. You can find an example in the attached github for a classification problem

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# !pip install concrete-autoencoder
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.layers import Dense, Dropout, LeakyReLU, Softmax
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: concrete-autoencoder in /usr/local/lib/python3.8/dist-packages (0.0.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.8/dist-packages (from concrete-autoencoder) (2.11.0)

# %%
def load_data(csv_path, feature_col_start, feature_col_end, target_col):
    """
    Load a CSV file into a Pandas DataFrame,drop Nan, and separate the feature and target columns.

    Parameters:
        csv_path (str): Path to the CSV file to load.
        feature_col_start, feature_col_end, (ints): Range of column indices to use as features.
        target_col (str or int): Name or index of the column to use as target.

    Returns:
        new_df: A df containing the features + labels DataFrame.
    """
    # Load CSV into a Pandas DataFrame
    df = pd.read_csv(csv_path)

    # drop nan
    df = df.dropna()

    # Extract the feature and target columns
    new_df = df[df.columns[feature_col_start: feature_col_end]]
    new_df[target_col] = df[target_col]

    return new_df

# %%
def split_data(df, target_col, test_size=0.3, random_state=42):
    """
    Splits the input DataFrame into training and testing sets.
    
    Parameters:
    -----------
    df (pandas DataFrame): The input DataFrame containing the features and target variable.
    target_col (str): The name of the target column in the DataFrame.
    test_size (float, optional): The proportion of the data to use for testing (default=0.3).
    random_state (int, optional): The random seed to use for the train-test split (default=42).
        
    Returns:
    --------
    X_train (pandas DataFrame): The training set features.     
    X_test (pandas DataFrame): The testing set features.        
    y_train (pandas Series): The training set target variable.
    y_test (pandas Series): The testing set target variable.
    """
    # Extract the features and target variable from the DataFrame
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    # Return the training and testing sets
    return X_train, X_test, y_train, y_test

# %%
def sort_df_by_important_features(df, X_train, X_test, target_col, top_K_bands):
    """
    Sorts the dataframe columns by their importance using the Concrete Autoencoder Feature Selector.

    Args:
        df (pd.DataFrame): The original dataframe to sort.
        X_train (np.ndarray): The training data to use in the feature selector.
        X_test (np.ndarray): The testing data to use in the feature selector.
        target_col (str): The name of the target column in the dataframe.
        top_K_bands (int): The number of most important features to select.

    Returns:
        pd.DataFrame: A new dataframe containing only the top K most important features and the target column.
    """
    def f(x):

        x = Dense(180)(x)  # apply a fully connected layer with 180 units
        x = LeakyReLU(0.2)(x)  # apply a leaky ReLU activation function
        x = Dropout(0.1)(x)  # apply dropout regularization
        x = Dense(180)(x)  # apply another fully connected layer with 180 units
        x = LeakyReLU(0.2)(x)  # apply another leaky ReLU activation function
        x = Dropout(0.1)(x)  # apply another dropout regularization
        x = Dense(204)(x)  # apply a final fully connected layer with 204 units
        return x

    def g(x):

        x = Dense(180)(x)  # apply a fully connected layer with 180 units
        x = LeakyReLU(0.2)(x)  # apply a leaky ReLU activation function
        x = Dropout(0.1)(x)  # apply dropout regularization
        x = Dense(1800)(x)  # apply another fully connected layer with 1800 units
        x = LeakyReLU(0.2)(x)  # apply another leaky ReLU activation function
        x = Dropout(0.1)(x)  # apply another dropout regularization
        x = Dense(10)(x)  # apply a final fully connected layer with 10 units
        x = LeakyReLU(1)(x)  # apply a final leaky ReLU activation function
        return x

    # create a ConcreteAutoencoderFeatureSelector object with the given output function and number of epochs
    selector = ConcreteAutoencoderFeatureSelector(K=top_K_bands, output_function=f, num_epochs=25)
    # fit the feature selector using the training data
    selector.fit(X_train, X_train, X_test, X_test)
    # get the indices of the top K most important features
    bands_list = selector.get_support(indices=True).tolist()
    # create a new dataframe containing only the top K most important features and the target column
    sorted_df = df[df.columns[bands_list]]
    sorted_df[target_col] = df[target_col]
    return sorted_df

# %% [markdown]
# ## Example

# %%
# Define input parameters
csv_path = '/content/data.csv'
feature_idx_i,feature_idx_f = 16,-2 # columns index of features
target_col = 'A' # labael column (regression)

# Number of features to get:
top_K_bands = 20

# %%
# Load data
data = load_data(csv_path, feature_idx_i,feature_idx_f, target_col)
data.head()
# Out:
# <ipython-input-2-629dbe82679f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[target_col] = df[target_col]
#      397.32     400.2    403.09    405.97    408.85    411.74    414.63  \
# 0  0.179808  0.152106  0.129191  0.115715  0.107613  0.102074  0.101501
# 1  0.221156  0.186298  0.160032  0.146194  0.136323  0.128331  0.124891
# 2  0.221893  0.185626  0.164002  0.154074  0.146511  0.137888  0.133002
# 3  0.162126  0.129779  0.104428  0.089685  0.080833  0.075142  0.068085
# 4  0.206857  0.164631  0.137415  0.118823  0.102912  0.097850  0.090029
#
#      417.52     420.4    423.29  ...    978.88    981.96    985.05    988.13  \
# 0  0.099727  0.096248  0.096929  ...  0.458213  0.464172  0.458520  0.462214
# 1  0.121850  0.116359  0.114495  ...  0.717970  0.717748  0.722268  0.726763
# 2  0.130920  0.128935  0.126446  ...  0.670528  0.675308  0.669332  0.689363
# 3  0.063978  0.058188  0.054447  ...  0.570670  0.574177  0.580435  0.579218
# 4  0.084146  0.077650  0.072445  ...  0.602451  0.609186  0.624415  0.622750
#
#      991.22    994.31     997.4   1000.49   1003.58         A
# 0  0.467727  0.467549  0.466043  0.471523  0.447471  2.017270
# 1  0.738159  0.741649  0.739217  0.762054  0.622104  1.872474
# 2  0.685825  0.698885  0.689815  0.705207  0.580815  2.043818
# 3  0.582644  0.592902  0.597743  0.609343  0.480618  2.123489
# 4  0.633371  0.640970  0.649146  0.659158  0.536100  2.122085
#
# [5 rows x 205 columns]

# %%
X_train, X_test, y_train, y_test = split_data(data, target_col, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((429, 204), (184, 204), (429,), (184,))

# %%
sorted_df =  sort_df_by_important_features(data,X_train, X_test,target_col,top_K_bands)
sorted_df
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 204)]             0
#
#  concrete_select (ConcreteSe  (None, 20)               4081
#  lect)
#
#  dense (Dense)               (None, 180)               3780
#
#  leaky_re_lu (LeakyReLU)     (None, 180)               0
#
#  dropout (Dropout)           (None, 180)               0
#
#  dense_1 (Dense)             (None, 180)               32580
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 180)               0
#
#  dropout_1 (Dropout)         (None, 180)               0
#
#  dense_2 (Dense)             (None, 204)               36924
#
# =================================================================
# Total params: 77,365
# Trainable params: 77,364
# Non-trainable params: 1
# _________________________________________________________________
# None
# mean max of probabilities: 0.006013051 - temperature 10.0
# Epoch 1/25
# 27/27 [==============================] - 1s 16ms/step - loss: 0.0713 - val_loss: 0.0096
# mean max of probabilities: 0.006015287 - temperature 7.663795
# Epoch 2/25
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0067
# mean max of probabilities: 0.0060147364 - temperature 5.873378
# Epoch 3/25
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0061 - val_loss: 0.0068
# mean max of probabilities: 0.0060150633 - temperature 4.5012374
# Epoch 4/25
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0052 - val_loss: 0.0056
# mean max of probabilities: 0.006015125 - temperature 3.4496577
# Epoch 5/25
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0047
# mean max of probabilities: 0.0060171178 - temperature 2.6437483
# Epoch 6/25
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0040 - val_loss: 0.0063
# mean max of probabilities: 0.0060177865 - temperature 2.0261152
# Epoch 7/25
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0032
# mean max of probabilities: 0.006018539 - temperature 1.552774
# Epoch 8/25
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0040 - val_loss: 0.0034
# mean max of probabilities: 0.0060456432 - temperature 1.1900141
# Epoch 9/25
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0051
# mean max of probabilities: 0.0060570203 - temperature 0.91200274
# Epoch 10/25
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0074 - val_loss: 0.0070
# mean max of probabilities: 0.0060855635 - temperature 0.6989404
# Epoch 11/25
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0101 - val_loss: 0.0026
# mean max of probabilities: 0.0061028227 - temperature 0.5356537
# Epoch 12/25
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0090 - val_loss: 0.0025
# mean max of probabilities: 0.006121438 - temperature 0.41051406
# Epoch 13/25
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0020
# mean max of probabilities: 0.006118839 - temperature 0.31460962
# Epoch 14/25
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0032
# mean max of probabilities: 0.00612284 - temperature 0.24111047
# Epoch 15/25
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0044
# mean max of probabilities: 0.006121397 - temperature 0.18478216
# Epoch 16/25
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0019
# mean max of probabilities: 0.0061243395 - temperature 0.1416133
# Epoch 17/25
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0066
# mean max of probabilities: 0.006134527 - temperature 0.10852956
# Epoch 18/25
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0041
# mean max of probabilities: 0.0061371536 - temperature 0.1
# Epoch 19/25
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0100
# mean max of probabilities: 0.006135746 - temperature 0.1
# Epoch 20/25
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0028
# mean max of probabilities: 0.0061376872 - temperature 0.1
# Epoch 21/25
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0083
# mean max of probabilities: 0.0061418726 - temperature 0.1
# Epoch 22/25
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0132
# mean max of probabilities: 0.006150574 - temperature 0.1
# Epoch 23/25
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0037
# mean max of probabilities: 0.006158702 - temperature 0.1
# Epoch 24/25
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0062
# mean max of probabilities: 0.006156838 - temperature 0.1
# Epoch 25/25
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0052
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 204)]             0
#
#  concrete_select (ConcreteSe  (None, 20)               4081
#  lect)
#
#  dense_3 (Dense)             (None, 180)               3780
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 180)               0
#
#  dropout_2 (Dropout)         (None, 180)               0
#
#  dense_4 (Dense)             (None, 180)               32580
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 180)               0
#
#  dropout_3 (Dropout)         (None, 180)               0
#
#  dense_5 (Dense)             (None, 204)               36924
#
# =================================================================
# Total params: 77,365
# Trainable params: 77,364
# Non-trainable params: 1
# _________________________________________________________________
# None
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# mean max of probabilities: 0.0059950966 - temperature 10.0
# Epoch 1/50
# 27/27 [==============================] - 1s 14ms/step - loss: 0.0853 - val_loss: 0.0114
# mean max of probabilities: 0.0059970096 - temperature 8.754307
# Epoch 2/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0051
# mean max of probabilities: 0.0059968373 - temperature 7.6637883
# Epoch 3/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0048
# mean max of probabilities: 0.005995857 - temperature 6.709115
# Epoch 4/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0055
# mean max of probabilities: 0.005996452 - temperature 5.8733654
# Epoch 5/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0047
# mean max of probabilities: 0.005996219 - temperature 5.1417246
# Epoch 6/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0043
# mean max of probabilities: 0.0059959195 - temperature 4.5012255
# Epoch 7/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0069
# mean max of probabilities: 0.0059988596 - temperature 3.940511
# Epoch 8/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0164
# mean max of probabilities: 0.006001671 - temperature 3.4496443
# Epoch 9/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0178
# mean max of probabilities: 0.0060096537 - temperature 3.0199244
# Epoch 10/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0371
# mean max of probabilities: 0.0060204617 - temperature 2.643735
# Epoch 11/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0430
# mean max of probabilities: 0.0060348557 - temperature 2.314407
# Epoch 12/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0867
# mean max of probabilities: 0.006043675 - temperature 2.0261035
# Epoch 13/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.1308
# mean max of probabilities: 0.006053866 - temperature 1.7737134
# Epoch 14/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0801
# mean max of probabilities: 0.0060644294 - temperature 1.552763
# Epoch 15/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.1025
# mean max of probabilities: 0.0060930443 - temperature 1.3593359
# Epoch 16/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0590
# mean max of probabilities: 0.006117232 - temperature 1.1900042
# Epoch 17/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.1125
# mean max of probabilities: 0.0061608693 - temperature 1.041766
# Epoch 18/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.1902
# mean max of probabilities: 0.0061950544 - temperature 0.911994
# Epoch 19/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0642
# mean max of probabilities: 0.006229147 - temperature 0.79838765
# Epoch 20/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.1385
# mean max of probabilities: 0.006258422 - temperature 0.69893295
# Epoch 21/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0789
# mean max of probabilities: 0.0062685935 - temperature 0.6118672
# Epoch 22/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0089
# mean max of probabilities: 0.0062896414 - temperature 0.5356475
# Epoch 23/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0844
# mean max of probabilities: 0.0062957616 - temperature 0.4689223
# Epoch 24/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0465
# mean max of probabilities: 0.0062988536 - temperature 0.4105089
# Epoch 25/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0619
# mean max of probabilities: 0.0063015716 - temperature 0.35937217
# Epoch 26/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0456
# mean max of probabilities: 0.0063049286 - temperature 0.3146054
# Epoch 27/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0083
# mean max of probabilities: 0.0063213212 - temperature 0.27541524
# Epoch 28/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0952
# mean max of probabilities: 0.006346191 - temperature 0.24110691
# Epoch 29/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0366
# mean max of probabilities: 0.0063543627 - temperature 0.21107239
# Epoch 30/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0209
# mean max of probabilities: 0.006361102 - temperature 0.18477927
# Epoch 31/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0087 - val_loss: 0.0253
# mean max of probabilities: 0.006366537 - temperature 0.16176143
# Epoch 32/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0580
# mean max of probabilities: 0.006371625 - temperature 0.14161095
# Epoch 33/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0068
# mean max of probabilities: 0.006364611 - temperature 0.12397055
# Epoch 34/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0238
# mean max of probabilities: 0.0063759563 - temperature 0.10852763
# Epoch 35/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0097
# mean max of probabilities: 0.0063816993 - temperature 0.1
# Epoch 36/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0022
# mean max of probabilities: 0.0063817427 - temperature 0.1
# Epoch 37/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0194
# mean max of probabilities: 0.006385335 - temperature 0.1
# Epoch 38/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0113
# mean max of probabilities: 0.0063899197 - temperature 0.1
# Epoch 39/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0108
# mean max of probabilities: 0.0064061 - temperature 0.1
# Epoch 40/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0028
# mean max of probabilities: 0.006406428 - temperature 0.1
# Epoch 41/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0144
# mean max of probabilities: 0.006417232 - temperature 0.1
# Epoch 42/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0040
# mean max of probabilities: 0.006429718 - temperature 0.1
# Epoch 43/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0086
# mean max of probabilities: 0.006437487 - temperature 0.1
# Epoch 44/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0224
# mean max of probabilities: 0.0064409217 - temperature 0.1
# Epoch 45/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0022
# mean max of probabilities: 0.00644094 - temperature 0.1
# Epoch 46/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0119
# mean max of probabilities: 0.0064468333 - temperature 0.1
# Epoch 47/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0034
# mean max of probabilities: 0.0064503634 - temperature 0.1
# Epoch 48/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0050
# mean max of probabilities: 0.006451911 - temperature 0.1
# Epoch 49/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0047
# mean max of probabilities: 0.006453401 - temperature 0.1
# Epoch 50/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0111
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 204)]             0
#
#  concrete_select (ConcreteSe  (None, 20)               4081
#  lect)
#
#  dense_6 (Dense)             (None, 180)               3780
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 180)               0
#
#  dropout_4 (Dropout)         (None, 180)               0
#
#  dense_7 (Dense)             (None, 180)               32580
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 180)               0
#
#  dropout_5 (Dropout)         (None, 180)               0
#
#  dense_8 (Dense)             (None, 204)               36924
#
# =================================================================
# Total params: 77,365
# Trainable params: 77,364
# Non-trainable params: 1
# _________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# None
# mean max of probabilities: 0.006016708 - temperature 10.0
# Epoch 1/100
# 27/27 [==============================] - 1s 14ms/step - loss: 0.0793 - val_loss: 0.0088
# mean max of probabilities: 0.00602386 - temperature 9.356454
# Epoch 2/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0058
# mean max of probabilities: 0.0060253525 - temperature 8.754322
# Epoch 3/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0076
# mean max of probabilities: 0.0060266717 - temperature 8.190941
# Epoch 4/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0072
# mean max of probabilities: 0.0060276412 - temperature 7.6638165
# Epoch 5/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0064
# mean max of probabilities: 0.0060287677 - temperature 7.170615
# Epoch 6/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0091
# mean max of probabilities: 0.006030131 - temperature 6.709152
# Epoch 7/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0098
# mean max of probabilities: 0.0060319216 - temperature 6.2773857
# Epoch 8/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0105
# mean max of probabilities: 0.0060342527 - temperature 5.873406
# Epoch 9/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0217
# mean max of probabilities: 0.006036726 - temperature 5.495424
# Epoch 10/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0182
# mean max of probabilities: 0.006039918 - temperature 5.1417685
# Epoch 11/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0201
# mean max of probabilities: 0.006045205 - temperature 4.810873
# Epoch 12/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0473
# mean max of probabilities: 0.006052129 - temperature 4.5012703
# Epoch 13/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0388
# mean max of probabilities: 0.006057716 - temperature 4.211592
# Epoch 14/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0382
# mean max of probabilities: 0.006062864 - temperature 3.9405565
# Epoch 15/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.1285
# mean max of probabilities: 0.006073637 - temperature 3.686963
# Epoch 16/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.1320
# mean max of probabilities: 0.0060853665 - temperature 3.4496894
# Epoch 17/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.1320
# mean max of probabilities: 0.006101788 - temperature 3.2276847
# Epoch 18/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.1611
# mean max of probabilities: 0.0061191 - temperature 3.0199678
# Epoch 19/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.1791
# mean max of probabilities: 0.0061402023 - temperature 2.825619
# Epoch 20/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.1994
# mean max of probabilities: 0.006165086 - temperature 2.6437776
# Epoch 21/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0020 - val_loss: 0.1824
# mean max of probabilities: 0.0061840056 - temperature 2.4736383
# Epoch 22/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.1810
# mean max of probabilities: 0.00620893 - temperature 2.3144479
# Epoch 23/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.2407
# mean max of probabilities: 0.006232263 - temperature 2.1655014
# Epoch 24/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.1534
# mean max of probabilities: 0.0062506893 - temperature 2.026142
# Epoch 25/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.2169
# mean max of probabilities: 0.0062784017 - temperature 1.8957505
# Epoch 26/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.1530
# mean max of probabilities: 0.0063000754 - temperature 1.7737503
# Epoch 27/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.1329
# mean max of probabilities: 0.0063190907 - temperature 1.6596013
# Epoch 28/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.1571
# mean max of probabilities: 0.006332888 - temperature 1.5527984
# Epoch 29/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.2299
# mean max of probabilities: 0.006350839 - temperature 1.4528686
# Epoch 30/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.1958
# mean max of probabilities: 0.0063848635 - temperature 1.35937
# Epoch 31/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.1445
# mean max of probabilities: 0.0064230682 - temperature 1.2718881
# Epoch 32/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.2159
# mean max of probabilities: 0.0064510787 - temperature 1.1900363
# Epoch 33/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.1832
# mean max of probabilities: 0.0064561553 - temperature 1.1134517
# Epoch 34/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.1446
# mean max of probabilities: 0.006473873 - temperature 1.0417962
# Epoch 35/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 0.1352
# mean max of probabilities: 0.00650405 - temperature 0.9747517
# Epoch 36/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0525
# mean max of probabilities: 0.0065180836 - temperature 0.9120219
# Epoch 37/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.2112
# mean max of probabilities: 0.006547076 - temperature 0.853329
# Epoch 38/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.1724
# mean max of probabilities: 0.0065705664 - temperature 0.7984133
# Epoch 39/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.1410
# mean max of probabilities: 0.006604711 - temperature 0.7470315
# Epoch 40/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0879
# mean max of probabilities: 0.0066275164 - temperature 0.6989566
# Epoch 41/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0431
# mean max of probabilities: 0.0066487393 - temperature 0.6539754
# Epoch 42/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0771
# mean max of probabilities: 0.006685324 - temperature 0.6118892
# Epoch 43/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.1205
# mean max of probabilities: 0.0067058927 - temperature 0.57251096
# Epoch 44/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0784
# mean max of probabilities: 0.0067147696 - temperature 0.5356672
# Epoch 45/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0484
# mean max of probabilities: 0.006734348 - temperature 0.5011946
# Epoch 46/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.1207
# mean max of probabilities: 0.0067600757 - temperature 0.4689403
# Epoch 47/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0315
# mean max of probabilities: 0.006767438 - temperature 0.4387618
# Epoch 48/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0792
# mean max of probabilities: 0.006791358 - temperature 0.4105254
# Epoch 49/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0090 - val_loss: 0.0943
# mean max of probabilities: 0.006800761 - temperature 0.3841061
# Epoch 50/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.1107
# mean max of probabilities: 0.006797695 - temperature 0.3593871
# Epoch 51/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0884
# mean max of probabilities: 0.0068082632 - temperature 0.33625883
# Epoch 52/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0677
# mean max of probabilities: 0.0068238056 - temperature 0.314619
# Epoch 53/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0333
# mean max of probabilities: 0.006830129 - temperature 0.2943718
# Epoch 54/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0305
# mean max of probabilities: 0.0068351426 - temperature 0.27542758
# Epoch 55/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0481
# mean max of probabilities: 0.006838113 - temperature 0.25770256
# Epoch 56/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0709
# mean max of probabilities: 0.0068419045 - temperature 0.24111822
# Epoch 57/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0505
# mean max of probabilities: 0.006854777 - temperature 0.22560112
# Epoch 58/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0586
# mean max of probabilities: 0.006868922 - temperature 0.21108262
# Epoch 59/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0154
# mean max of probabilities: 0.0068763075 - temperature 0.1974985
# Epoch 60/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0133
# mean max of probabilities: 0.006880696 - temperature 0.18478854
# Epoch 61/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0276
# mean max of probabilities: 0.0068727992 - temperature 0.17289653
# Epoch 62/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0222
# mean max of probabilities: 0.006873223 - temperature 0.16176982
# Epoch 63/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0232
# mean max of probabilities: 0.006880461 - temperature 0.15135914
# Epoch 64/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0255
# mean max of probabilities: 0.006900774 - temperature 0.14161845
# Epoch 65/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0519
# mean max of probabilities: 0.006905193 - temperature 0.13250463
# Epoch 66/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0154
# mean max of probabilities: 0.0069092466 - temperature 0.12397734
# Epoch 67/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0111
# mean max of probabilities: 0.006909316 - temperature 0.115998805
# Epoch 68/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0140
# mean max of probabilities: 0.006909877 - temperature 0.10853373
# Epoch 69/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0081
# mean max of probabilities: 0.006908572 - temperature 0.101549104
# Epoch 70/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0176
# mean max of probabilities: 0.0069155 - temperature 0.1
# Epoch 71/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0331
# mean max of probabilities: 0.0069207796 - temperature 0.1
# Epoch 72/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0416
# mean max of probabilities: 0.006927094 - temperature 0.1
# Epoch 73/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0147
# mean max of probabilities: 0.0069297315 - temperature 0.1
# Epoch 74/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0275
# mean max of probabilities: 0.0069412193 - temperature 0.1
# Epoch 75/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0065
# mean max of probabilities: 0.0069453856 - temperature 0.1
# Epoch 76/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0220
# mean max of probabilities: 0.006944473 - temperature 0.1
# Epoch 77/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0197
# mean max of probabilities: 0.0069471747 - temperature 0.1
# Epoch 78/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0126
# mean max of probabilities: 0.006947222 - temperature 0.1
# Epoch 79/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0177
# mean max of probabilities: 0.006947155 - temperature 0.1
# Epoch 80/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0062 - val_loss: 0.0172
# mean max of probabilities: 0.0069464245 - temperature 0.1
# Epoch 81/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0281
# mean max of probabilities: 0.0069534937 - temperature 0.1
# Epoch 82/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0147
# mean max of probabilities: 0.006960203 - temperature 0.1
# Epoch 83/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0143
# mean max of probabilities: 0.0069630304 - temperature 0.1
# Epoch 84/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0114
# mean max of probabilities: 0.0069712223 - temperature 0.1
# Epoch 85/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0197
# mean max of probabilities: 0.0069755176 - temperature 0.1
# Epoch 86/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0258
# mean max of probabilities: 0.0069690435 - temperature 0.1
# Epoch 87/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0146
# mean max of probabilities: 0.006971825 - temperature 0.1
# Epoch 88/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0105
# mean max of probabilities: 0.006974916 - temperature 0.1
# Epoch 89/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0103
# mean max of probabilities: 0.006975402 - temperature 0.1
# Epoch 90/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0127
# mean max of probabilities: 0.006969919 - temperature 0.1
# Epoch 91/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0048
# mean max of probabilities: 0.0069722338 - temperature 0.1
# Epoch 92/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 0.0056
# mean max of probabilities: 0.0069720224 - temperature 0.1
# Epoch 93/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0135
# mean max of probabilities: 0.0069677085 - temperature 0.1
# Epoch 94/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0064
# mean max of probabilities: 0.0069673443 - temperature 0.1
# Epoch 95/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 0.0147
# mean max of probabilities: 0.0069683837 - temperature 0.1
# Epoch 96/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0084
# mean max of probabilities: 0.006973116 - temperature 0.1
# Epoch 97/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0191
# mean max of probabilities: 0.006982795 - temperature 0.1
# Epoch 98/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0038
# mean max of probabilities: 0.006992766 - temperature 0.1
# Epoch 99/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0061 - val_loss: 0.0073
# mean max of probabilities: 0.0069942838 - temperature 0.1
# Epoch 100/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0118
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 204)]             0
#
#  concrete_select (ConcreteSe  (None, 20)               4081
#  lect)
#
#  dense_9 (Dense)             (None, 180)               3780
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 180)               0
#
#  dropout_6 (Dropout)         (None, 180)               0
#
#  dense_10 (Dense)            (None, 180)               32580
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 180)               0
#
#  dropout_7 (Dropout)         (None, 180)               0
#
#  dense_11 (Dense)            (None, 204)               36924
#
# =================================================================
# Total params: 77,365
# Trainable params: 77,364
# Non-trainable params: 1
# _________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# None
# mean max of probabilities: 0.0059922365 - temperature 10.0
# Epoch 1/200
# 27/27 [==============================] - 1s 13ms/step - loss: 0.0782 - val_loss: 0.0241
# mean max of probabilities: 0.0059942612 - temperature 9.672865
# Epoch 2/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0106
# mean max of probabilities: 0.0059896046 - temperature 9.356432
# Epoch 3/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0051
# mean max of probabilities: 0.005988942 - temperature 9.050355
# Epoch 4/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0051
# mean max of probabilities: 0.0059885215 - temperature 8.754288
# Epoch 5/200
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0057
# mean max of probabilities: 0.005987818 - temperature 8.467904
# Epoch 6/200
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0049
# mean max of probabilities: 0.005986646 - temperature 8.190891
# Epoch 7/200
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0342
# mean max of probabilities: 0.005986704 - temperature 7.9229407
# Epoch 8/200
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0371
# mean max of probabilities: 0.005987694 - temperature 7.663756
# Epoch 9/200
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0619
# mean max of probabilities: 0.0059908433 - temperature 7.4130487
# Epoch 10/200
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0521
# mean max of probabilities: 0.0059937234 - temperature 7.170543
# Epoch 11/200
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.1442
# mean max of probabilities: 0.0059984745 - temperature 6.9359717
# Epoch 12/200
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.1204
# mean max of probabilities: 0.0060021016 - temperature 6.709073
# Epoch 13/200
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.1760
# mean max of probabilities: 0.0060089943 - temperature 6.4895983
# Epoch 14/200
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.1800
# mean max of probabilities: 0.0060178963 - temperature 6.2773023
# Epoch 15/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.1842
# mean max of probabilities: 0.0060269255 - temperature 6.0719514
# Epoch 16/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.2049
# mean max of probabilities: 0.0060389284 - temperature 5.8733177
# Epoch 17/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.2359
# mean max of probabilities: 0.006049346 - temperature 5.681182
# Epoch 18/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.2869
# mean max of probabilities: 0.00606592 - temperature 5.495332
# Epoch 19/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.2532
# mean max of probabilities: 0.0060784915 - temperature 5.315562
# Epoch 20/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.2798
# mean max of probabilities: 0.0060940227 - temperature 5.141673
# Epoch 21/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.2523
# mean max of probabilities: 0.0061065354 - temperature 4.973472
# Epoch 22/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.2313
# mean max of probabilities: 0.0061223754 - temperature 4.810774
# Epoch 23/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.2164
# mean max of probabilities: 0.006138395 - temperature 4.653398
# Epoch 24/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.2370
# mean max of probabilities: 0.0061565526 - temperature 4.5011706
# Epoch 25/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.2451
# mean max of probabilities: 0.006174082 - temperature 4.353923
# Epoch 26/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.2495
# mean max of probabilities: 0.0061901277 - temperature 4.2114906
# Epoch 27/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.2691
# mean max of probabilities: 0.0062090764 - temperature 4.0737195
# Epoch 28/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.2144
# mean max of probabilities: 0.0062247897 - temperature 3.940455
# Epoch 29/200
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.2428
# mean max of probabilities: 0.006250062 - temperature 3.8115504
# Epoch 30/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.2333
# mean max of probabilities: 0.0062715276 - temperature 3.686862
# Epoch 31/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.2501
# mean max of probabilities: 0.006292127 - temperature 3.5662534
# Epoch 32/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.2671
# mean max of probabilities: 0.0063166977 - temperature 3.4495895
# Epoch 33/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.2461
# mean max of probabilities: 0.0063355514 - temperature 3.3367422
# Epoch 34/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.2351
# mean max of probabilities: 0.0063593136 - temperature 3.2275858
# Epoch 35/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.2610
# mean max of probabilities: 0.006384206 - temperature 3.122001
# Epoch 36/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.2064
# mean max of probabilities: 0.006393621 - temperature 3.01987
# Epoch 37/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.2284
# mean max of probabilities: 0.0064025954 - temperature 2.9210799
# Epoch 38/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.2411
# mean max of probabilities: 0.006417214 - temperature 2.825522
# Epoch 39/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.2637
# mean max of probabilities: 0.0064398996 - temperature 2.7330897
# Epoch 40/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.2345
# mean max of probabilities: 0.00646061 - temperature 2.6436808
# Epoch 41/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.2265
# mean max of probabilities: 0.006480823 - temperature 2.5571983
# Epoch 42/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.1820
# mean max of probabilities: 0.006504084 - temperature 2.473544
# Epoch 43/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.2494
# mean max of probabilities: 0.00653801 - temperature 2.3926258
# Epoch 44/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.1993
# mean max of probabilities: 0.006547286 - temperature 2.314355
# Epoch 45/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.1881
# mean max of probabilities: 0.0065642633 - temperature 2.238644
# Epoch 46/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.2168
# mean max of probabilities: 0.006594716 - temperature 2.1654105
# Epoch 47/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.2350
# mean max of probabilities: 0.006622006 - temperature 2.0945728
# Epoch 48/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.2035
# mean max of probabilities: 0.006642297 - temperature 2.0260522
# Epoch 49/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.2119
# mean max of probabilities: 0.006653736 - temperature 1.9597738
# Epoch 50/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.1979
# mean max of probabilities: 0.00667025 - temperature 1.8956633
# Epoch 51/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.2143
# mean max of probabilities: 0.0067077726 - temperature 1.8336499
# Epoch 52/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.1400
# mean max of probabilities: 0.006714986 - temperature 1.7736648
# Epoch 53/200
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0023 - val_loss: 0.1636
# mean max of probabilities: 0.006718865 - temperature 1.7156423
# Epoch 54/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.1220
# mean max of probabilities: 0.0067324503 - temperature 1.6595179
# Epoch 55/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.1690
# mean max of probabilities: 0.0067567592 - temperature 1.6052297
# Epoch 56/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.1651
# mean max of probabilities: 0.006794648 - temperature 1.5527177
# Epoch 57/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.1878
# mean max of probabilities: 0.0068112416 - temperature 1.5019232
# Epoch 58/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.1869
# mean max of probabilities: 0.006834944 - temperature 1.4527898
# Epoch 59/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.1741
# mean max of probabilities: 0.006847029 - temperature 1.4052644
# Epoch 60/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.1014
# mean max of probabilities: 0.006870131 - temperature 1.3592935
# Epoch 61/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0978
# mean max of probabilities: 0.0068913996 - temperature 1.3148265
# Epoch 62/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.1251
# mean max of probabilities: 0.006910513 - temperature 1.2718145
# Epoch 63/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.1305
# mean max of probabilities: 0.0069173323 - temperature 1.2302092
# Epoch 64/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.1623
# mean max of probabilities: 0.0069321888 - temperature 1.189965
# Epoch 65/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.1348
# mean max of probabilities: 0.006955984 - temperature 1.1510376
# Epoch 66/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.2311
# mean max of probabilities: 0.006973879 - temperature 1.1133835
# Epoch 67/200
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0616
# mean max of probabilities: 0.0069701285 - temperature 1.0769612
# Epoch 68/200
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0971
# mean max of probabilities: 0.0069924546 - temperature 1.0417303
# Epoch 69/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.1044
# mean max of probabilities: 0.0070112785 - temperature 1.007652
# Epoch 70/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0924
# mean max of probabilities: 0.0070366613 - temperature 0.9746885
# Epoch 71/200
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.1359
# mean max of probabilities: 0.0070474134 - temperature 0.94280314
# Epoch 72/200
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 0.1183
# mean max of probabilities: 0.0070623932 - temperature 0.9119609
# Epoch 73/200
# ...
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0065
# mean max of probabilities: 0.009532084 - temperature 0.1
# Epoch 320/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0126
# mean max of probabilities: 0.009513857 - temperature 0.1
# Epoch 321/400
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0017
# mean max of probabilities: 0.009518215 - temperature 0.1
# Epoch 322/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0021
# mean max of probabilities: 0.009519311 - temperature 0.1
# Epoch 323/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0025
# mean max of probabilities: 0.009508729 - temperature 0.1
# Epoch 324/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0013
# mean max of probabilities: 0.009508766 - temperature 0.1
# Epoch 325/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0014
# mean max of probabilities: 0.009506918 - temperature 0.1
# Epoch 326/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0020
# mean max of probabilities: 0.009514036 - temperature 0.1
# Epoch 327/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0014
# mean max of probabilities: 0.009529804 - temperature 0.1
# Epoch 328/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0016
# mean max of probabilities: 0.009528594 - temperature 0.1
# Epoch 329/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# mean max of probabilities: 0.009531309 - temperature 0.1
# Epoch 330/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0048
# mean max of probabilities: 0.009531652 - temperature 0.1
# Epoch 331/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0018
# mean max of probabilities: 0.009536878 - temperature 0.1
# Epoch 332/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0018
# mean max of probabilities: 0.009538392 - temperature 0.1
# Epoch 333/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0012
# mean max of probabilities: 0.009543624 - temperature 0.1
# Epoch 334/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0014
# mean max of probabilities: 0.009542686 - temperature 0.1
# Epoch 335/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0023
# mean max of probabilities: 0.00954331 - temperature 0.1
# Epoch 336/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0028
# mean max of probabilities: 0.009542411 - temperature 0.1
# Epoch 337/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0024
# mean max of probabilities: 0.0095431 - temperature 0.1
# Epoch 338/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0014
# mean max of probabilities: 0.009527512 - temperature 0.1
# Epoch 339/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0018
# mean max of probabilities: 0.009522672 - temperature 0.1
# Epoch 340/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0016
# mean max of probabilities: 0.009523551 - temperature 0.1
# Epoch 341/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0092
# mean max of probabilities: 0.009525801 - temperature 0.1
# Epoch 342/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0025
# mean max of probabilities: 0.009543704 - temperature 0.1
# Epoch 343/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0035
# mean max of probabilities: 0.00956368 - temperature 0.1
# Epoch 344/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0021
# mean max of probabilities: 0.009567733 - temperature 0.1
# Epoch 345/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0013
# mean max of probabilities: 0.009568827 - temperature 0.1
# Epoch 346/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0013
# mean max of probabilities: 0.009576215 - temperature 0.1
# Epoch 347/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0016
# mean max of probabilities: 0.009581043 - temperature 0.1
# Epoch 348/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0015
# mean max of probabilities: 0.009582281 - temperature 0.1
# Epoch 349/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0032
# mean max of probabilities: 0.0095869545 - temperature 0.1
# Epoch 350/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0019
# mean max of probabilities: 0.0095795365 - temperature 0.1
# Epoch 351/400
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0017
# mean max of probabilities: 0.0095672505 - temperature 0.1
# Epoch 352/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0026
# mean max of probabilities: 0.009578867 - temperature 0.1
# Epoch 353/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0023
# mean max of probabilities: 0.009573759 - temperature 0.1
# Epoch 354/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0017
# mean max of probabilities: 0.009571944 - temperature 0.1
# Epoch 355/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0021
# mean max of probabilities: 0.009571002 - temperature 0.1
# Epoch 356/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0021
# mean max of probabilities: 0.009571629 - temperature 0.1
# Epoch 357/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0017
# mean max of probabilities: 0.009574354 - temperature 0.1
# Epoch 358/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0014
# mean max of probabilities: 0.0095780585 - temperature 0.1
# Epoch 359/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0015
# mean max of probabilities: 0.009583304 - temperature 0.1
# Epoch 360/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0040
# mean max of probabilities: 0.009582902 - temperature 0.1
# Epoch 361/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0015
# mean max of probabilities: 0.009583759 - temperature 0.1
# Epoch 362/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0039
# mean max of probabilities: 0.009611504 - temperature 0.1
# Epoch 363/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0020
# mean max of probabilities: 0.009629063 - temperature 0.1
# Epoch 364/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0049
# mean max of probabilities: 0.009647474 - temperature 0.1
# Epoch 365/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0036
# mean max of probabilities: 0.009652173 - temperature 0.1
# Epoch 366/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0031
# mean max of probabilities: 0.009658375 - temperature 0.1
# Epoch 367/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0022
# mean max of probabilities: 0.009651295 - temperature 0.1
# Epoch 368/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0012
# mean max of probabilities: 0.009665029 - temperature 0.1
# Epoch 369/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0016
# mean max of probabilities: 0.009664455 - temperature 0.1
# Epoch 370/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0038
# mean max of probabilities: 0.009645596 - temperature 0.1
# Epoch 371/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0039
# mean max of probabilities: 0.0096469745 - temperature 0.1
# Epoch 372/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 0.0018
# mean max of probabilities: 0.009650512 - temperature 0.1
# Epoch 373/400
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0054
# mean max of probabilities: 0.009657729 - temperature 0.1
# Epoch 374/400
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0021
# mean max of probabilities: 0.0096595315 - temperature 0.1
# Epoch 375/400
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0014
# mean max of probabilities: 0.009659863 - temperature 0.1
# Epoch 376/400
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0011
# mean max of probabilities: 0.009653578 - temperature 0.1
# Epoch 377/400
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0026
# mean max of probabilities: 0.009659819 - temperature 0.1
# Epoch 378/400
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0016
# mean max of probabilities: 0.0096810525 - temperature 0.1
# Epoch 379/400
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0019
# mean max of probabilities: 0.00968488 - temperature 0.1
# Epoch 380/400
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0011
# mean max of probabilities: 0.009682099 - temperature 0.1
# Epoch 381/400
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0047
# mean max of probabilities: 0.009681413 - temperature 0.1
# Epoch 382/400
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0064
# mean max of probabilities: 0.009686256 - temperature 0.1
# Epoch 383/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0023
# mean max of probabilities: 0.009690069 - temperature 0.1
# Epoch 384/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0011
# mean max of probabilities: 0.009687772 - temperature 0.1
# Epoch 385/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0014
# mean max of probabilities: 0.00968728 - temperature 0.1
# Epoch 386/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0022
# mean max of probabilities: 0.0096926 - temperature 0.1
# Epoch 387/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0013
# mean max of probabilities: 0.009704767 - temperature 0.1
# Epoch 388/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0020
# mean max of probabilities: 0.00970805 - temperature 0.1
# Epoch 389/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0015
# mean max of probabilities: 0.009706628 - temperature 0.1
# Epoch 390/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0012
# mean max of probabilities: 0.009704234 - temperature 0.1
# Epoch 391/400
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0031 - val_loss: 0.0016
# mean max of probabilities: 0.0097285975 - temperature 0.1
# Epoch 392/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0027
# mean max of probabilities: 0.0097250985 - temperature 0.1
# Epoch 393/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0017
# mean max of probabilities: 0.009723704 - temperature 0.1
# Epoch 394/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# mean max of probabilities: 0.009725603 - temperature 0.1
# Epoch 395/400
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0025
# mean max of probabilities: 0.009740128 - temperature 0.1
# Epoch 396/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0025
# mean max of probabilities: 0.009746214 - temperature 0.1
# Epoch 397/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0015
# mean max of probabilities: 0.00974536 - temperature 0.1
# Epoch 398/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0024
# mean max of probabilities: 0.009749157 - temperature 0.1
# Epoch 399/400
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0013
# mean max of probabilities: 0.009755303 - temperature 0.1
# Epoch 400/400
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0013
# <ipython-input-4-7bbca7d4a2c8>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sorted_df[target_col] = df[target_col]
#        877.69    720.54    819.95    795.74    759.56    771.61    783.67  \
# 0    0.579423  0.292235  0.583753  0.562910  0.536819  0.549620  0.558424
# 1    0.885729  0.449958  0.894158  0.898464  0.864115  0.882618  0.890052
# 2    0.855833  0.433595  0.864074  0.866420  0.828052  0.848288  0.856138
# 3    0.748112  0.328464  0.753514  0.754643  0.719879  0.739644  0.746800
# 4    0.801877  0.369840  0.815905  0.821306  0.789060  0.807974  0.814888
# ..        ...       ...       ...       ...       ...       ...       ...
# 612  0.786732  0.333123  0.796363  0.791217  0.752083  0.774240  0.785829
# 613  0.364014  0.129281  0.346632  0.338186  0.310817  0.326364  0.332254
# 614  0.679027  0.354364  0.669369  0.659740  0.624200  0.644844  0.651237
# 615  0.532599  0.181478  0.537261  0.514193  0.478409  0.498795  0.508198
# 616  0.375948  0.151884  0.364027  0.357121  0.333547  0.344800  0.350789
#
#        720.54    813.89    783.67  ...    798.77    750.54    874.64  \
# 0    0.292235  0.573157  0.558424  ...  0.563612  0.517486  0.580026
# 1    0.449958  0.897237  0.890052  ...  0.898274  0.826603  0.884617
# 2    0.433595  0.857534  0.856138  ...  0.868170  0.791010  0.853694
# 3    0.328464  0.754795  0.746800  ...  0.756333  0.684226  0.747620
# 4    0.369840  0.820912  0.814888  ...  0.822021  0.748561  0.802887
# ..        ...       ...       ...  ...       ...       ...       ...
# 612  0.333123  0.796099  0.785829  ...  0.793076  0.710342  0.786948
# 613  0.129281  0.344831  0.332254  ...  0.340059  0.289555  0.362873
# 614  0.354364  0.661221  0.651237  ...  0.661552  0.595233  0.676018
# 615  0.181478  0.531458  0.508198  ...  0.515659  0.452294  0.531816
# 616  0.151884  0.364977  0.350789  ...  0.358645  0.312038  0.373765
#
#        741.53    829.04     871.6    826.01    753.55    819.95         A
# 0    0.473878  0.581986  0.582378  0.584543  0.525307  0.583753  2.017270
# 1    0.753038  0.896991  0.887789  0.896801  0.842405  0.894158  1.872474
# 2    0.720103  0.865504  0.857715  0.867874  0.805933  0.864074  2.043818
# 3    0.611263  0.755369  0.748048  0.757952  0.700228  0.753514  2.123489
# 4    0.671791  0.817139  0.803576  0.821392  0.767407  0.815905  2.122085
# ..        ...       ...       ...       ...       ...       ...       ...
# 612  0.629900  0.793902  0.787840  0.795306  0.728559  0.796363  4.258127
# 613  0.251838  0.350013  0.361193  0.348754  0.298084  0.346632  1.826188
# 614  0.543744  0.669436  0.678512  0.668166  0.609054  0.669369  0.933424
# 615  0.395480  0.526283  0.534131  0.530676  0.464050  0.537261  2.009618
# 616  0.275580  0.365481  0.373640  0.364977  0.322362  0.364027  1.190534
#
# [613 rows x 21 columns]
